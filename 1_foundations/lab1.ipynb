# %%
from dotenv import load_dotenv

# %%
load_dotenv(override=True)
# Out:
# True

# %%
import os

gemini_api_key = os.getenv("GEMINI_API_KEY")

if gemini_api_key:
    print(f"GEMINI_API_KEY is set and begins with: {gemini_api_key[:8]}")
else:
    print("GEMINI_API_KEY is not set – please check your .env file.")
# Out:
# GEMINI_API_KEY is set and begins with: AIzaSyAf

# %%
from openai import OpenAI
import os

# Gemini via the OpenAI-compatible endpoint
GEMINI_BASE_URL = "https://generativelanguage.googleapis.com/v1beta/openai"
model = "gemini-2.5-flash"

gemini_api_key = os.getenv("GEMINI_API_KEY")
if not gemini_api_key:
    raise ValueError("GEMINI_API_KEY is not set – please add it to your .env file.")

client = OpenAI(
    api_key=gemini_api_key,
    base_url=GEMINI_BASE_URL,
)

messages = [{"role": "user", "content": "What is 2+2?"}]

response = client.chat.completions.create(
    model=model,
    messages=messages,
)

print(response.choices[0].message.content)
# Out:
# 2 + 2 = 4

# %%
question = "Please propose a hard, challenging question to assess someone's IQ. Respond only with the question."
messages = [{"role": "user", "content": question}]

# %%
response = client.chat.completions.create(
    model=model,
    messages=messages,
)
question = response.choices[0].message.content

print(question)
# Out:
# Consider the operation $\circledast$:
#
# $6 \circledast 2 = 4$
# $3 \circledast 5 = 15$
# $8 \circledast 4 = 12$
# $7 \circledast 1 = 7$
# $10 \circledast 5 = 5$
#
# What is $9 \circledast 3$?

# %%
messages = [{"role": "user", "content": question}]

# %%
response = client.chat.completions.create(
    model=model,
    messages=messages,
)

answer = response.choices[0].message.content
print(answer)
# Out:
# Let's analyze the given examples to find the pattern for the operation $\circledast$:
#
# 1.  $6 \circledast 2 = 4$
# 2.  $3 \circledast 5 = 15$
# 3.  $8 \circledast 4 = 12$
# 4.  $7 \circledast 1 = 7$
# 5.  $10 \circledast 5 = 5$
#
# Let's test common arithmetic operations for each pair $(a, b)$:
#
# *   **Example 1: $6 \circledast 2 = 4$**
#     *   $6-2=4$ (Matches)
#     *   $6+2=8$ (No)
#     *   $6 \times 2=12$ (No)
#     *   $6/2=3$ (No)
#
# *   **Example 2: $3 \circledast 5 = 15$**
#     *   $3-5=-2$ (No)
#     *   $3+5=8$ (No)
#     *   $3 \times 5=15$ (Matches)
#     *   $3/5=0.6$ (No)
#
# *   **Example 3: $8 \circledast 4 = 12$**
#     *   $8-4=4$ (No)
#     *   $8+4=12$ (Matches)
#     *   $8 \times 4=32$ (No)
#     *   $8/4=2$ (No)
#
# *   **Example 4: $7 \circledast 1 = 7$**
#     *   $7-1=6$ (No)
#     *   $7+1=8$ (No)
#     *   $7 \times 1=7$ (Matches)
#     *   $7/1=7$ (Matches) - For simplicity, we'll assume multiplication here.
#
# ...

# %%
from IPython.display import Markdown, display
display(Markdown(answer))
# Out:
# Let's analyze the given examples to find the pattern for the operation $\circledast$:
#
# 1.  $6 \circledast 2 = 4$
# 2.  $3 \circledast 5 = 15$
# 3.  $8 \circledast 4 = 12$
# 4.  $7 \circledast 1 = 7$
# 5.  $10 \circledast 5 = 5$
#
# Let's test common arithmetic operations for each pair $(a, b)$:
#
# *   **Example 1: $6 \circledast 2 = 4$**
#     *   $6-2=4$ (Matches)
#     *   $6+2=8$ (No)
#     *   $6 \times 2=12$ (No)
#     *   $6/2=3$ (No)
#
# *   **Example 2: $3 \circledast 5 = 15$**
#     *   $3-5=-2$ (No)
#     *   $3+5=8$ (No)
#     *   $3 \times 5=15$ (Matches)
#     *   $3/5=0.6$ (No)
#
# *   **Example 3: $8 \circledast 4 = 12$**
#     *   $8-4=4$ (No)
#     *   $8+4=12$ (Matches)
#     *   $8 \times 4=32$ (No)
#     *   $8/4=2$ (No)
#
# *   **Example 4: $7 \circledast 1 = 7$**
#     *   $7-1=6$ (No)
#     *   $7+1=8$ (No)
#     *   $7 \times 1=7$ (Matches)
#     *   $7/1=7$ (Matches) - For simplicity, we'll assume multiplication here.
#
# ...

# %%
# First create the messages:

messages = [{"role": "user", "content": "pick a bussiness area that might be worth exploring for an agentic AI opportunity"}]

# Then make the first call:

response = client.chat.completions.create(
    model=model,
    messages=messages,
)

# Then read the business idea:

business_idea = response.choices[0].message.content

# And repeat! In the next message, include the business idea within the message

# %%
print(business_idea)
# Out:
# Okay, let's pick a business area ripe for agentic AI.
#
# The area I'd focus on is:
#
# **Autonomous Project & Workflow Orchestration (within defined domains)**
#
# This isn't just about automating individual tasks (like RPA), but about an AI agent taking on the *managerial* role of achieving a higher-level goal by coordinating tasks, resources, and even other AI agents or human team members.
#
# ---
#
# ### **The Opportunity: Autonomous Project & Workflow Orchestration**
#
# **1. The Problem Space:**
#
# *   **Complexity & Overhead:** Modern projects and operational workflows are incredibly complex, involving numerous interconnected tasks, dependencies, human resources, digital tools (SaaS applications, APIs), and external factors.
# *   **Human Bottlenecks:** Human project managers, product managers, or operations leads spend a significant portion of their time on coordination, tracking, communication, and reactive problem-solving, rather than strategic thinking.
# ...

# %%
# First create the messages:

messages = [{"role": "user", "content": "present a pan point that is based on following idea-something challenging that might be ripe for an agentic solution"+business_idea}]



response = client.chat.completions.create(
    model=model,
    messages=messages,
)



challenge = response.choices[0].message.content

# %%
print(challenge)
# Out:
# Okay, here is a "Pan Point" derived from your excellent breakdown, focusing on the core challenge and the agentic solution.
#
# ---
#
# ### **The Pan Point: Autonomous Cognitive Orchestration**
#
# **The greatest untapped efficiency challenge in enterprise today lies in the manual, bottleneck-ridden orchestration of complex projects and operational workflows.**
#
# **Agentic AI is poised to transform this by becoming the autonomous 'Cognitive Orchestrator' – a system that not only executes tasks but intelligently plans, adapts, monitors, and optimizes end-to-end operational flows, freeing human capital from tactical oversight to strategic innovation.**
#
# ---

# %%
# First create the messages:

messages = [{"role": "user", "content": "propose the adentic AI solution for the challenge"+challenge}]



response = client.chat.completions.create(
    model=model,
    messages=messages,
)



solution = response.choices[0].message.content
print(solution)
# Out:
# Okay, based on your "Pan Point" – focusing on **Autonomous Cognitive Orchestration** as the solution to **manual, bottleneck-ridden project and operational workflow orchestration** – here's an ad-centric AI solution proposal.
#
# ---
#
# ## **AegisFlow AI: Your Enterprise's Autonomous Cognitive Orchestrator.**
# *Unleash strategic innovation, eliminate operational friction.*
#
# ---
#
# ### **The Challenge We Solve (Your Pan Point):**
#
# Today's enterprises grapple with a fundamental, costly inefficiency: the **manual, bottleneck-ridden orchestration of complex projects and operational workflows.** This tactical oversight drains human capital, slows innovation, and introduces critical points of failure across the entire organizational landscape.
#
# ### **Introducing the Solution: AegisFlow AI**
#
# ...

# %%
display(Markdown(solution))
# Out:
# Okay, based on your "Pan Point" – focusing on **Autonomous Cognitive Orchestration** as the solution to **manual, bottleneck-ridden project and operational workflow orchestration** – here's an ad-centric AI solution proposal.
#
# ---
#
# ## **AegisFlow AI: Your Enterprise's Autonomous Cognitive Orchestrator.**
# *Unleash strategic innovation, eliminate operational friction.*
#
# ---
#
# ### **The Challenge We Solve (Your Pan Point):**
#
# Today's enterprises grapple with a fundamental, costly inefficiency: the **manual, bottleneck-ridden orchestration of complex projects and operational workflows.** This tactical oversight drains human capital, slows innovation, and introduces critical points of failure across the entire organizational landscape.
#
# ### **Introducing the Solution: AegisFlow AI**
#
# ...
